# %% [markdown]
# # Work with Model OOP
# > I have been working on the hacks from last week and figured out how to add classOf to the code.
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [jupyter, week-19]

# %%
import hashlib, os, binascii, json
from datetime import date

class User:    

    def __init__(self, name, uid, password, dob, classOf):
        self._name = name    # variables with self prefix become part of the object, 
        self._uid = uid
        self._password = set_password(password)
        self._dob = dob
        self._classOf = classOf 
    
    @property
    def name(self):
        return self._name
    
    # a setter function, allows name to be updated after initial object creation
    @name.setter
    def name(self, name):
        self._name = name
    
    # a getter method, extracts email from object
    @property
    def uid(self):
        return self._uid
    
    # a setter function, allows name to be updated after initial object creation
    @uid.setter
    def uid(self, uid):
        self._uid = uid
        
    # check if uid parameter matches user id in object, return boolean
    def is_uid(self, uid):
        return self._uid == uid
    
    # dob property is returned as string, to avoid unfriendly outcomes
    @property
    def dob(self):
        dob_string = self._dob.strftime('%m-%d-%Y')
        return dob_string
    
    # dob should be have verification for type date
    @dob.setter
    def dob(self, dob):
        self._dob = dob
        
    # age is calculated and returned each time it is accessed
    @property
    def age(self):
        today = date.today()
        return today.year - self._dob.year - ((today.month, today.day) < (self._dob.month, self._dob.day))

    @property
    def classOf(self):
        return self._classOf
    
    # a setter function, allows name to be updated after initial object creation
    @classOf.setter
    def classOf(self, classOf):
        self._classOf = classOf
    
    # dictionary is customized, removing password for security purposes
    @property
    def dictionary(self):
        dict = {
            "name" : self.name,
            "uid" : self.uid,
            "dob" : self.dob,
            "age" : self.age,
            "classOf" : self.classOf
        }
        return dict

         # output content using json dumps, this is ready for API response
    def __str__(self):
        return json.dumps(self.dictionary)
    
    # output command to recreate the object, uses attribute directly
    def __repr__(self):
        return f'User(name={self._name}, uid={self._uid}, password={self._password},dob={self._dob}, classOf={self.classOf})'
    
def set_password(password):
    salt = hashlib.sha256(os.urandom(60)).hexdigest().encode('ascii')
    pwdhash = hashlib.pbkdf2_hmac('sha512', password.encode('utf-8'), salt, 1000000)
    pwdhash = binascii.hexlify(pwdhash)
    return (salt + pwdhash).decode('ascii')

def pw_check(stored_password, provided_password):
    salt = stored_password[:64]
    pwdhash = hashlib.pbkdf2_hmac('sha512', provided_password.encode('utf-8'), salt.encode('ascii'), 1000000)
    stored_password = stored_password[64:]
    pwdhash = binascii.hexlify(pwdhash).decode('ascii')
    return pwdhash == stored_password
    
   
    

if __name__ == "__main__":
    u1 = User(name='Thomas Edison', uid='toby', password='123toby', dob=date(1847, 2, 11), classOf='2023')
    print("JSON ready string:\n", u1, "\n") 
    print("Raw Variables of object:\n", vars(u1), "\n") 
    print("Raw Attributes and Methods of object:\n", dir(u1), "\n")
    print("Representation to Re-Create the object:\n", repr(u1), "\n")
# Out:
# JSON ready string:
#  {"name": "Thomas Edison", "uid": "toby", "dob": "02-11-1847", "age": 176, "classOf": "2023"}
#
# Raw Variables of object:
#  {'_name': 'Thomas Edison', '_uid': 'toby', '_password': '3005b8c41409a27c1b865b8e5a238ba6d72d0f4dbf42ab679a0b6efe1206f0dd8937796a30469c6239d2cb3bf9f69652e1324c4b1a8f0abb090c8abfe7ba4ff457cd59b21d77d8761ce4c69aced4fbf6b2a1160575460edfc7a8c1e7a923dd81', '_dob': datetime.date(1847, 2, 11), '_classOf': '2023'}
#
# Raw Attributes and Methods of object:
#  ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_classOf', '_dob', '_name', '_password', '_uid', 'age', 'classOf', 'dictionary', 'dob', 'is_uid', 'name', 'uid']
#
# Representation to Re-Create the object:
#  User(name=Thomas Edison, uid=toby, password=3005b8c41409a27c1b865b8e5a238ba6d72d0f4dbf42ab679a0b6efe1206f0dd8937796a30469c6239d2cb3bf9f69652e1324c4b1a8f0abb090c8abfe7ba4ff457cd59b21d77d8761ce4c69aced4fbf6b2a1160575460edfc7a8c1e7a923dd81,dob=1847-02-11, classOf=2023)
